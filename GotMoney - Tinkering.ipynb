# %%
# Perform imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
file_Level1 = "./Resources/NCSSDataDictLevel1.txt"
file_Level2 = "./Resources/NCSSDataDictLevel2.txt"
file_Level3 = "./Resources/NCSSDataDictLevel3.txt"
file_Level4 = "./Resources/NCSSDataDictLevel4.txt"

dict_Level1 = pd.read_json(file_Level1)
dict_Level2 = pd.read_json(file_Level2)
dict_Level3 = pd.read_json(file_Level3)
dict_Level4 = pd.read_json(file_Level4)
print(dict_Level1)
print(dict_Level2)
print(dict_Level3)
print(dict_Level4)
# Out:
#           Description1
# O     Other Nonprofits
# PC      Public Charity
# PF  Private Foundation
# U              Unknown
#                     Description2
# M  Mutual Benefit Public Charity
# O       Operating Public Charity
# S      Supporting Public Charity
#                            Description3
# AR         Arts, culture and humanities
# ED                            Education
# EN                  Environment/animals
# HE                               Health
# HS                       Human Services
# IN       International, foreign affairs
# MO                 Other mutual benefit
# MR         Pension and retirement funds
# PB             Public, societal benefit
# RE                     Religion related
# UN                Unknown, unclassified
# ZA          Single organization support
# ZB  Fundraising within NTEE major group
# ZC      Private grantmaking foundations
# ZD                   Public foundations
# ZE                  General fundraising
# ZF      Other Supporting Public Benefit
#                                         Description4
#                                              Unknown
# A                      Arts, Culture, and Humanities
# B                                          Education
# C  Environmental Quality, Protection, and Beautif...
# D                                     Animal-Related
# E                                             Health
# F                 Mental Health, Crisis Intervention
# G           Diseases, Disorders, Medical Disciplines
# H                                   Medical Research
# I                               Crime, Legal Related
# J                            Employment, Job Related
# K                   Food, Agriculture, and Nutrition
# L                                   Housing, Shelter
# M                                      Public Safety
# N             Recreation, Sports, Leisure, Athletics
# O                                  Youth Development
# P            Human Services - Multipurpose and Other
# Q  International, Foreign Affairs, and National S...
# R              Civil Rights, Social Action, Advocacy
# S           Community Improvement, Capacity Building
# T  Philanthropy, Voluntarism, and Grantmaking Fou...
# U  Science and Technology Research Institutes, Se...
# V       Social Science Research Institutes, Services
# W   Public, Society Benefit - Multipurpose and Other
# X            Religion Related, Spiritual Development
# Y     Mutual/Membership Benefit Organizations, Other
# Z                                   Unknown\tUnknown

# %%
# specify file names
gov_data_file = "../../bookish-lamp/2018_BMF.csv"

# %%
# import files
gov_data = pd.read_csv(gov_data_file, low_memory=False)

# %%
# check the number of data rows per column
gov_data.count()
# Out:
# EIN          1499450
# SEC_NAME      404909
# FRCD         1499450
# SUBSECCD     1499450
# TAXPER       1240366
# ASSETS       1223112
# INCOME       1223112
# NAME         1499450
# ADDRESS      1499450
# CITY         1499450
# STATE        1498426
# NTEECONF        4518
# NTEEFINAL    1499450
# NAICS        1495191
# ZIP5         1499353
# OUTNCCS      1499450
# OUTREAS         3021
# RULEDATE     1499450
# FIPS         1496643
# FNDNCD       1499450
# PMSA          506362
# MSA_NECH     1175676
# CASSETS       542418
# CFINSRC       542418
# CTAXPER       542418
# CTOTREV       542418
# ACCPER       1240366
# RANDNUM      1499450
# NTEECC       1499450
# NTEE1        1499450
# LEVEL4       1499450
# LEVEL1       1499450
# NTMAJ10      1499450
# MAJGRPB      1499450
# LEVEL3       1499450
# LEVEL2       1499450
# NTMAJ12      1499450
# NTMAJ5       1499450
# FILER        1499450
# ZFILER       1499450
# dtype: int64

# %%
# display the data read in
gov_data
# Out:
#                EIN                       SEC_NAME  FRCD  SUBSECCD    TAXPER  \
# 0            19818                           3514    60         3       NaN
# 1            29215                            NaN    60         3       NaN
# 2           260049                            NaN    60         3       NaN
# 3           490336                            NaN    60         3       NaN
# 4           587764                            NaN    60         3       NaN
# ...            ...                            ...   ...       ...       ...
# 1499445  996089401                            NaN     1         3  201803.0
# 1499446  996165005  145 PHILOTESIAN REBEKAH LODGE    20         8  201712.0
# 1499447  998010224                            NaN     1         3  201612.0
# 1499448  998997790                   YOUNG RIDERS    20         3  201708.0
# 1499449  999009356                            NaN    20         5  201712.0
#
#            ASSETS    INCOME                                             NAME  \
# 0             NaN       NaN                     PALMER SECOND BAPTIST CHURCH
# 1             NaN       NaN                              ST GEORGE CATHEDRAL
# 2             NaN       NaN                           CORINTH BAPTIST CHURCH
# 3             NaN       NaN                          EASTSIDE BAPTIST CHURCH
# 4             NaN       NaN                             IGLESIA BETHESDA INC
# ...           ...       ...                                              ...
# 1499445  670570.0  160467.0                      TOYO SAKUMOTO CHARITABLE TR
# 1499446       0.0       0.0                 INDEPENDENT ORDER OF ODD FELLOWS
# 1499447  737906.0  177689.0                  HAWAII FOUNDATION FOR THE BLIND
# 1499448       0.0       0.0  CHAMPAIGN COUNTY EXTENSION EDUCATION FOUNDATION
# 1499449       0.0       0.0          NATIONAL ASSOCIATION OF LETTER CARRIERS
#
#                              ADDRESS          CITY  ... LEVEL4 LEVEL1 NTMAJ10  \
# 0                  1050 THORNDIKE ST        PALMER  ...      X     PC      RE
# 1                     523 E BROADWAY  SOUTH BOSTON  ...      X     PC      RE
# 2                          PO BOX 92       HOSFORD  ...      X     PC      RE
# 3                         PO BOX 296       LABELLE  ...      X     PC      RE
# 4                     157 ANDOVER ST        LOWELL  ...      X     PC      RE
# ...                              ...           ...  ...    ...    ...     ...
# 1499445                  PO BOX 3170      HONOLULU  ...      T     PF      PU
# 1499446                    PO BOX 76     CUPERTINO  ...      Y      O      MU
# 1499447  225 LILIUOKALANI AVE APT 5D      HONOLULU  ...      P     PF      HU
# 1499448            1120 N WEBSTER ST   TAYLORVILLE  ...      B     PC      ED
# 1499449                 PO BOX 25854      HONOLULU  ...      J      O      HU
#
#          MAJGRPB  LEVEL3 LEVEL2 NTMAJ12  NTMAJ5  FILER  ZFILER
# 0              X      RE      O      RE      OT      N       N
# 1              X      RE      O      RE      OT      N       N
# 2              X      RE      O      RE      OT      N       N
# 3              X      RE      O      RE      OT      N       N
# 4              X      RE      O      RE      OT      N       N
# ...          ...     ...    ...     ...     ...    ...     ...
# 1499445        T      ZC      S      PU      OT      Y       N
# 1499446        Y      MO      M      MU      OT      Y       Y
# 1499447        P      HS      O      HU      HU      Y       N
# 1499448        B      ZA      S      ED      ED      Y       Y
# 1499449        J      HS      O      HU      HU      Y       Y
#
# [1499450 rows x 40 columns]

# %%
# identify the indices of rows we want to eliminate
indexNames = gov_data[gov_data["LEVEL1"]=="O"].index

# %%
len(indexNames)
# Out:
# 349167

# %%
gov_data.drop(indexNames, inplace=True)

# %%
gov_data
# Out:
#                EIN                 SEC_NAME  FRCD  SUBSECCD    TAXPER  \
# 0            19818                     3514    60         3       NaN
# 1            29215                      NaN    60         3       NaN
# 2           260049                      NaN    60         3       NaN
# 3           490336                      NaN    60         3       NaN
# 4           587764                      NaN    60         3       NaN
# ...            ...                      ...   ...       ...       ...
# 1499443  996087839       CARTWRIGHT RACHAEL     3         3  201712.0
# 1499444  996088748  PACIFIC CENTURY TR TTEE     1         3  201803.0
# 1499445  996089401                      NaN     1         3  201803.0
# 1499447  998010224                      NaN     1         3  201612.0
# 1499448  998997790             YOUNG RIDERS    20         3  201708.0
#
#            ASSETS    INCOME                                             NAME  \
# 0             NaN       NaN                     PALMER SECOND BAPTIST CHURCH
# 1             NaN       NaN                              ST GEORGE CATHEDRAL
# 2             NaN       NaN                           CORINTH BAPTIST CHURCH
# 3             NaN       NaN                          EASTSIDE BAPTIST CHURCH
# 4             NaN       NaN                             IGLESIA BETHESDA INC
# ...           ...       ...                                              ...
# 1499443   10109.0   22000.0                             KEIKI KOHOLA PROJECT
# 1499444  377564.0   64829.0                               UNOYO KOJIMA TRUST
# 1499445  670570.0  160467.0                      TOYO SAKUMOTO CHARITABLE TR
# 1499447  737906.0  177689.0                  HAWAII FOUNDATION FOR THE BLIND
# 1499448       0.0       0.0  CHAMPAIGN COUNTY EXTENSION EDUCATION FOUNDATION
#
#                              ADDRESS          CITY  ... LEVEL4 LEVEL1 NTMAJ10  \
# 0                  1050 THORNDIKE ST        PALMER  ...      X     PC      RE
# 1                     523 E BROADWAY  SOUTH BOSTON  ...      X     PC      RE
# 2                          PO BOX 92       HOSFORD  ...      X     PC      RE
# 3                         PO BOX 296       LABELLE  ...      X     PC      RE
# 4                     157 ANDOVER ST        LOWELL  ...      X     PC      RE
# ...                              ...           ...  ...    ...    ...     ...
# 1499443          1330 SABAL LAKES RD  DELRAY BEACH  ...      U     PF      PU
# 1499444                  PO BOX 3170      HONOLULU  ...      T     PF      PU
# 1499445                  PO BOX 3170      HONOLULU  ...      T     PF      PU
# 1499447  225 LILIUOKALANI AVE APT 5D      HONOLULU  ...      P     PF      HU
# 1499448            1120 N WEBSTER ST   TAYLORVILLE  ...      B     PC      ED
#
#          MAJGRPB  LEVEL3 LEVEL2 NTMAJ12  NTMAJ5  FILER  ZFILER
# 0              X      RE      O      RE      OT      N       N
# 1              X      RE      O      RE      OT      N       N
# 2              X      RE      O      RE      OT      N       N
# 3              X      RE      O      RE      OT      N       N
# 4              X      RE      O      RE      OT      N       N
# ...          ...     ...    ...     ...     ...    ...     ...
# 1499443        U      PB      S      PU      OT      Y       N
# 1499444        T      ZC      S      PU      OT      Y       N
# 1499445        T      ZC      S      PU      OT      Y       N
# 1499447        P      HS      O      HU      HU      Y       N
# 1499448        B      ZA      S      ED      ED      Y       Y
#
# [1150283 rows x 40 columns]

# %%
# identify the indices of rows we want to eliminate
indexNames = gov_data[gov_data["LEVEL1"]=="U"].index

# %%
len(indexNames)
# Out:
# 30

# %%
gov_data.drop(indexNames, inplace=True)

# %%
gov_data.head()
# Out:
#       EIN SEC_NAME  FRCD  SUBSECCD  TAXPER  ASSETS  INCOME  \
# 0   19818     3514    60         3     NaN     NaN     NaN
# 1   29215      NaN    60         3     NaN     NaN     NaN
# 2  260049      NaN    60         3     NaN     NaN     NaN
# 3  490336      NaN    60         3     NaN     NaN     NaN
# 4  587764      NaN    60         3     NaN     NaN     NaN
#
#                            NAME            ADDRESS          CITY  ... LEVEL4  \
# 0  PALMER SECOND BAPTIST CHURCH  1050 THORNDIKE ST        PALMER  ...      X
# 1           ST GEORGE CATHEDRAL     523 E BROADWAY  SOUTH BOSTON  ...      X
# 2        CORINTH BAPTIST CHURCH          PO BOX 92       HOSFORD  ...      X
# 3       EASTSIDE BAPTIST CHURCH         PO BOX 296       LABELLE  ...      X
# 4          IGLESIA BETHESDA INC     157 ANDOVER ST        LOWELL  ...      X
#
#   LEVEL1 NTMAJ10  MAJGRPB  LEVEL3 LEVEL2 NTMAJ12  NTMAJ5  FILER  ZFILER
# 0     PC      RE        X      RE      O      RE      OT      N       N
# 1     PC      RE        X      RE      O      RE      OT      N       N
# 2     PC      RE        X      RE      O      RE      OT      N       N
# 3     PC      RE        X      RE      O      RE      OT      N       N
# 4     PC      RE        X      RE      O      RE      OT      N       N
#
# [5 rows x 40 columns]

# %%
gov_data.dropna(axis=0, how='any', subset=["ASSETS", "INCOME","LEVEL1", "NAME", "STATE"], inplace=True)

# %%
gov_data = gov_data[["EIN","ASSETS","INCOME","NAME","ADDRESS","CITY","STATE","ZIP5","LEVEL1","LEVEL2","LEVEL3","LEVEL4"]]

# %%
gov_data
# Out:
#                EIN    ASSETS    INCOME  \
# 18        10002847       0.0       0.0
# 19        10011694       0.0       0.0
# 20        10015091   52489.0  107989.0
# 21        10017496  233819.0  180773.0
# 33        10024155       0.0       0.0
# ...            ...       ...       ...
# 1499443  996087839   10109.0   22000.0
# 1499444  996088748  377564.0   64829.0
# 1499445  996089401  670570.0  160467.0
# 1499447  998010224  737906.0  177689.0
# 1499448  998997790       0.0       0.0
#
#                                                     NAME  \
# 18                   HULLS COVE NEIGHBORHOOD ASSOCIATION
# 19                  MASSACHUSETTS MODERATORS ASSOCIATION
# 20                               HANOVER SOCCER CLUB INC
# 21                        AGAMENTICUS YACHT CLUB OF YORK
# 33                                           BANGOR BAND
# ...                                                  ...
# 1499443                             KEIKI KOHOLA PROJECT
# 1499444                               UNOYO KOJIMA TRUST
# 1499445                      TOYO SAKUMOTO CHARITABLE TR
# 1499447                  HAWAII FOUNDATION FOR THE BLIND
# 1499448  CHAMPAIGN COUNTY EXTENSION EDUCATION FOUNDATION
#
#                              ADDRESS          CITY STATE     ZIP5 LEVEL1  \
# 18                        PO BOX 126    HULLS COVE    ME   4644.0     PC
# 19             30 SAMUEL PRESCOTT DR          STOW    MA   1775.0     PC
# 20                         PO BOX 13  CEDAR KNOLLS    NJ   7927.0     PC
# 21                        PO BOX 534   YORK HARBOR    ME   3911.0     PC
# 33                   647 MAIN STREET        BANGOR    ME   4401.0     PC
# ...                              ...           ...   ...      ...    ...
# 1499443          1330 SABAL LAKES RD  DELRAY BEACH    FL  93035.0     PF
# 1499444                  PO BOX 3170      HONOLULU    HI  96802.0     PF
# 1499445                  PO BOX 3170      HONOLULU    HI  96802.0     PF
# 1499447  225 LILIUOKALANI AVE APT 5D      HONOLULU    HI  96815.0     PF
# 1499448            1120 N WEBSTER ST   TAYLORVILLE    IL  62568.0     PC
#
#         LEVEL2 LEVEL3 LEVEL4
# 18           O     PB      S
# 19           O     PB      S
# 20           O     HS      N
# 21           O     HS      N
# 33           O     AR      A
# ...        ...    ...    ...
# 1499443      S     PB      U
# 1499444      S     ZC      T
# 1499445      S     ZC      T
# 1499447      O     HS      P
# 1499448      S     ZA      B
#
# [891408 rows x 12 columns]

# %%
gov_data.count()
# Out:
# EIN        891408
# ASSETS     891408
# INCOME     891408
# NAME       891408
# ADDRESS    891408
# CITY       891408
# STATE      891408
# ZIP5       891382
# LEVEL1     891408
# LEVEL2     891408
# LEVEL3     891408
# LEVEL4     891408
# dtype: int64

# %%
gov_data.describe()
# Out:
#                 EIN        ASSETS        INCOME           ZIP5
# count  8.914080e+05  8.914080e+05  8.914080e+05  891382.000000
# mean   4.501007e+08  5.560271e+06  3.733421e+06   49563.756665
# std    2.390812e+08  1.752903e+08  1.782037e+08   30230.675916
# min    1.000285e+07  0.000000e+00 -3.050449e+07       0.000000
# 25%    2.631331e+08  0.000000e+00  0.000000e+00   22314.000000
# 50%    4.527022e+08  3.790000e+03  4.860000e+03   46904.000000
# 75%    5.825405e+08  2.846955e+05  1.976800e+05   77382.000000
# max    9.989978e+08  5.207875e+10  7.235283e+10   99950.000000

# %%
state_level1 = gov_data.copy()
state_level1
# Out:
#                EIN    ASSETS    INCOME  \
# 18        10002847       0.0       0.0
# 19        10011694       0.0       0.0
# 20        10015091   52489.0  107989.0
# 21        10017496  233819.0  180773.0
# 33        10024155       0.0       0.0
# ...            ...       ...       ...
# 1499443  996087839   10109.0   22000.0
# 1499444  996088748  377564.0   64829.0
# 1499445  996089401  670570.0  160467.0
# 1499447  998010224  737906.0  177689.0
# 1499448  998997790       0.0       0.0
#
#                                                     NAME  \
# 18                   HULLS COVE NEIGHBORHOOD ASSOCIATION
# 19                  MASSACHUSETTS MODERATORS ASSOCIATION
# 20                               HANOVER SOCCER CLUB INC
# 21                        AGAMENTICUS YACHT CLUB OF YORK
# 33                                           BANGOR BAND
# ...                                                  ...
# 1499443                             KEIKI KOHOLA PROJECT
# 1499444                               UNOYO KOJIMA TRUST
# 1499445                      TOYO SAKUMOTO CHARITABLE TR
# 1499447                  HAWAII FOUNDATION FOR THE BLIND
# 1499448  CHAMPAIGN COUNTY EXTENSION EDUCATION FOUNDATION
#
#                              ADDRESS          CITY STATE     ZIP5 LEVEL1  \
# 18                        PO BOX 126    HULLS COVE    ME   4644.0     PC
# 19             30 SAMUEL PRESCOTT DR          STOW    MA   1775.0     PC
# 20                         PO BOX 13  CEDAR KNOLLS    NJ   7927.0     PC
# 21                        PO BOX 534   YORK HARBOR    ME   3911.0     PC
# 33                   647 MAIN STREET        BANGOR    ME   4401.0     PC
# ...                              ...           ...   ...      ...    ...
# 1499443          1330 SABAL LAKES RD  DELRAY BEACH    FL  93035.0     PF
# 1499444                  PO BOX 3170      HONOLULU    HI  96802.0     PF
# 1499445                  PO BOX 3170      HONOLULU    HI  96802.0     PF
# 1499447  225 LILIUOKALANI AVE APT 5D      HONOLULU    HI  96815.0     PF
# 1499448            1120 N WEBSTER ST   TAYLORVILLE    IL  62568.0     PC
#
#         LEVEL2 LEVEL3 LEVEL4
# 18           O     PB      S
# 19           O     PB      S
# 20           O     HS      N
# 21           O     HS      N
# 33           O     AR      A
# ...        ...    ...    ...
# 1499443      S     PB      U
# 1499444      S     ZC      T
# 1499445      S     ZC      T
# 1499447      O     HS      P
# 1499448      S     ZA      B
#
# [891408 rows x 12 columns]

# %%
state_level1 = state_level1.groupby(["STATE", "LEVEL1"], as_index=False).aggregate(
    {
        "INCOME":["mean", "sem", "count", "min", "max", "median"],
        "ASSETS":["mean", "sem", "count", "min", "max", "median"]
    }
)
state_level1
# Out:
#     STATE LEVEL1        INCOME                                              \
#                           mean           sem  count      min           max
# 0      AA     PC  0.000000e+00           NaN      1      0.0  0.000000e+00
# 1      AE     PC  7.268707e+05  6.340133e+05     21      0.0  1.329001e+07
# 2      AK     PC  1.829941e+06  4.558748e+05   2788      0.0  8.759308e+08
# 3      AK     PF  3.081849e+06  1.315174e+06    110      0.0  1.320134e+08
# 4      AL     PC  1.275886e+06  2.325689e+05  10542      0.0  1.868716e+09
# ..    ...    ...           ...           ...    ...      ...           ...
# 112    WI     PF  1.612918e+06  2.897912e+05   2375  -6126.0  6.120344e+08
# 113    WV     PC  2.150192e+06  4.157335e+05   5007      0.0  1.160407e+09
# 114    WV     PF  8.708717e+05  1.505691e+05    353 -30617.0  2.874431e+07
# 115    WY     PC  6.374540e+05  1.370712e+05   2399      0.0  2.690173e+08
# 116    WY     PF  1.783573e+06  4.317716e+05    286      0.0  9.130250e+07
#
#                      ASSETS
#        median          mean           sem  count  min           max    median
# 0         0.0  0.000000e+00           NaN      1  0.0  0.000000e+00       0.0
# 1         0.0  4.598413e+05  3.953394e+05     21  0.0  8.306423e+06       0.0
# 2        23.0  2.672440e+06  4.970286e+05   2788  0.0  7.510723e+08       1.0
# 3    101937.5  1.029920e+07  6.500200e+06    110  0.0  7.116767e+08  339912.5
# 4         0.0  1.963709e+06  2.645897e+05  10542  0.0  1.193380e+09       0.0
# ..        ...           ...           ...    ...  ...           ...       ...
# 112  150243.0  4.229250e+06  5.070854e+05   2375  0.0  8.494265e+08  586919.0
# 113       0.0  2.828019e+06  5.662661e+05   5007  0.0  1.690946e+09       0.0
# 114  100762.0  2.889246e+06  4.668270e+05    353  0.0  1.143525e+08  477387.0
# 115       0.0  1.383387e+06  3.336089e+05   2399  0.0  6.481097e+08       0.0
# 116  138517.5  4.115691e+06  6.646454e+05    286  0.0  1.165312e+08  667078.5
#
# [117 rows x 14 columns]

# %%
state_level1.dropna(axis=0, how='any', inplace=True)
state_level1
# Out:
#     STATE LEVEL1        INCOME                                              \
#                           mean           sem  count      min           max
# 1      AE     PC  7.268707e+05  6.340133e+05     21      0.0  1.329001e+07
# 2      AK     PC  1.829941e+06  4.558748e+05   2788      0.0  8.759308e+08
# 3      AK     PF  3.081849e+06  1.315174e+06    110      0.0  1.320134e+08
# 4      AL     PC  1.275886e+06  2.325689e+05  10542      0.0  1.868716e+09
# 5      AL     PF  9.482565e+05  1.277176e+05   1094      0.0  8.172473e+07
# ..    ...    ...           ...           ...    ...      ...           ...
# 112    WI     PF  1.612918e+06  2.897912e+05   2375  -6126.0  6.120344e+08
# 113    WV     PC  2.150192e+06  4.157335e+05   5007      0.0  1.160407e+09
# 114    WV     PF  8.708717e+05  1.505691e+05    353 -30617.0  2.874431e+07
# 115    WY     PC  6.374540e+05  1.370712e+05   2399      0.0  2.690173e+08
# 116    WY     PF  1.783573e+06  4.317716e+05    286      0.0  9.130250e+07
#
#                      ASSETS
#        median          mean           sem  count  min           max    median
# 1         0.0  4.598413e+05  3.953394e+05     21  0.0  8.306423e+06       0.0
# 2        23.0  2.672440e+06  4.970286e+05   2788  0.0  7.510723e+08       1.0
# 3    101937.5  1.029920e+07  6.500200e+06    110  0.0  7.116767e+08  339912.5
# 4         0.0  1.963709e+06  2.645897e+05  10542  0.0  1.193380e+09       0.0
# 5    102247.5  2.544636e+06  3.112035e+05   1094  0.0  1.770920e+08  382920.5
# ..        ...           ...           ...    ...  ...           ...       ...
# 112  150243.0  4.229250e+06  5.070854e+05   2375  0.0  8.494265e+08  586919.0
# 113       0.0  2.828019e+06  5.662661e+05   5007  0.0  1.690946e+09       0.0
# 114  100762.0  2.889246e+06  4.668270e+05    353  0.0  1.143525e+08  477387.0
# 115       0.0  1.383387e+06  3.336089e+05   2399  0.0  6.481097e+08       0.0
# 116  138517.5  4.115691e+06  6.646454e+05    286  0.0  1.165312e+08  667078.5
#
# [112 rows x 14 columns]

# %%
state_PC = state_level1[state_level1["LEVEL1"] == "PC"]
state_PC = state_PC.set_index("STATE")
state_PC

state_PF = state_level1[state_level1["LEVEL1"] == "PF"]
state_PF = state_PF.set_index("STATE")
state_PF
# Out:
#       LEVEL1        INCOME                                                 \
#                       mean           sem  count         min           max
# STATE
# AK        PF  3.081849e+06  1.315174e+06    110         0.0  1.320134e+08
# AL        PF  9.482565e+05  1.277176e+05   1094         0.0  8.172473e+07
# AR        PF  8.221813e+06  5.319360e+06    445    -96310.0  2.328780e+09
# AZ        PF  1.269739e+06  2.103552e+05   1072         0.0  1.556742e+08
# CA        PF  4.119017e+06  4.322736e+05   9922   -771027.0  1.805736e+09
# CO        PF  1.888632e+06  5.414098e+05   1733   -705762.0  9.057607e+08
# CT        PF  2.528523e+06  4.569301e+05   1702         0.0  5.445726e+08
# DC        PF  5.083051e+06  1.450270e+06    475         0.0  5.786544e+08
# DE        PF  2.192138e+07  1.953696e+07   1446   -321035.0  2.824998e+10
# FL        PF  1.893818e+06  4.667277e+05   6401   -457625.0  2.872420e+09
# GA        PF  2.447939e+06  3.706305e+05   1942 -30504486.0  3.781977e+08
# HI        PF  1.314268e+06  4.072178e+05    452    -35854.0  1.706108e+08
# IA        PF  1.101363e+06  2.012223e+05   1007    -96960.0  1.082862e+08
# ID        PF  2.665753e+06  1.173871e+06    335         0.0  2.751052e+08
# IL        PF  2.757566e+06  5.688776e+05   5380  -4982912.0  2.120009e+09
# IN        PF  2.771959e+06  8.299118e+05   1322     -1500.0  8.271905e+08
# KS        PF  1.224610e+06  2.004417e+05    850    -40333.0  1.068525e+08
# KY        PF  1.841383e+06  4.423033e+05    708         0.0  2.057403e+08
# LA        PF  1.512394e+06  2.704393e+05    730      -989.0  1.136419e+08
# MA        PF  3.098993e+06  6.696240e+05   3449   -798164.0  1.733115e+09
# MD        PF  3.120029e+06  8.139810e+05   1760     -3594.0  1.135050e+09
# ME        PF  2.018346e+06  7.869670e+05    474         0.0  3.541296e+08
# MI        PF  3.562637e+06  8.994176e+05   2458     -5202.0  1.881601e+09
# MN        PF  3.806438e+06  1.039537e+06   1449         0.0  1.096147e+09
# MO        PF  2.728150e+06  9.442072e+05   1503     -3589.0  1.367874e+09
# MS        PF  1.047074e+06  1.834945e+05    364         0.0  4.786371e+07
# MT        PF  2.289591e+06  1.496655e+06    344         0.0  5.114071e+08
# NC        PF  2.840617e+06  1.183669e+06   2368   -102815.0  2.640420e+09
# ND        PF  9.350364e+05  2.318778e+05    136         0.0  1.804563e+07
# NE        PF  3.553031e+06  1.002181e+06    608         0.0  3.362898e+08
# NH        PF  3.222391e+06  1.920568e+06    515         0.0  9.751198e+08
# NJ        PF  3.654820e+06  7.844910e+05   3284  -2521696.0  1.763269e+09
# NM        PF  1.277807e+06  3.224417e+05    377         0.0  7.537232e+07
# NV        PF  1.007465e+06  1.527184e+05   2492   -226925.0  2.028828e+08
# NY        PF  4.074081e+06  4.300268e+05  11076 -14430637.0  2.178794e+09
# OH        PF  1.453359e+06  1.359972e+05   3538      -346.0  2.797062e+08
# OK        PF  9.224017e+06  6.445712e+06    968   -880557.0  6.188592e+09
# OR        PF  2.113550e+06  4.745299e+05    832   -215798.0  2.626056e+08
# PA        PF  2.325393e+06  4.960916e+05   5144  -5498247.0  1.736330e+09
# PR        PF  1.541127e+06  7.888038e+05     22         0.0  1.563172e+07
# RI        PF  1.290417e+06  1.309723e+05   1759         0.0  1.447582e+08
# SC        PF  1.380852e+06  4.134631e+05    718         0.0  2.742173e+08
# SD        PF  5.374847e+06  3.686764e+06    190         1.0  6.949228e+08
# TN        PF  1.622852e+06  2.773258e+05   1089         0.0  2.147144e+08
# TX        PF  2.853306e+06  3.093818e+05   5867  -9539996.0  1.152474e+09
# UT        PF  1.448429e+06  3.617652e+05    870    -13504.0  2.340683e+08
# VA        PF  1.598364e+06  1.837519e+05   1852    -18470.0  1.478550e+08
# VI        PF  9.700527e+05  6.838051e+05     11         0.0  7.712892e+06
# VT        PF  9.746376e+05  1.982088e+05    273   -542505.0  2.974945e+07
# WA        PF  4.908737e+07  4.258605e+07   1540   -223153.0  6.535132e+10
# WI        PF  1.612918e+06  2.897912e+05   2375     -6126.0  6.120344e+08
# WV        PF  8.708717e+05  1.505691e+05    353    -30617.0  2.874431e+07
# WY        PF  1.783573e+06  4.317716e+05    286         0.0  9.130250e+07
#
#                        ASSETS                                          \
#          median          mean           sem  count  min           max
# STATE
# AK     101937.5  1.029920e+07  6.500200e+06    110  0.0  7.116767e+08
# AL     102247.5  2.544636e+06  3.112035e+05   1094  0.0  1.770920e+08
# AR      68188.0  1.451183e+07  7.581225e+06    445  0.0  3.131554e+09
# AZ      79397.5  4.117232e+06  7.517834e+05   1072  0.0  5.410745e+08
# CA     102806.0  1.290699e+07  1.863713e+06   9922  0.0  1.039132e+10
# CO      87083.0  6.351334e+06  1.175850e+06   1733  0.0  1.234717e+09
# CT     146494.0  5.753870e+06  8.299997e+05   1702  0.0  7.993502e+08
# DC     242874.0  1.730527e+07  5.225601e+06    475  0.0  2.171861e+09
# DE     343269.5  8.372265e+06  1.872607e+06   1446  0.0  2.451297e+09
# FL     112610.0  4.398461e+06  5.778441e+05   6401  0.0  2.485088e+09
# GA      86908.5  5.700686e+06  7.504542e+05   1942  0.0  5.732169e+08
# HI      99260.5  4.684526e+06  1.011676e+06    452  0.0  3.103798e+08
# IA      61020.0  3.407070e+06  5.697618e+05   1007  0.0  3.814846e+08
# ID      61289.0  5.261540e+06  1.946091e+06    335  0.0  5.493861e+08
# IL     164354.0  6.663230e+06  1.231139e+06   5380  0.0  6.295202e+09
# IN      93950.5  1.426809e+07  8.888254e+06   1322  0.0  1.166343e+10
# KS      77280.0  5.111681e+06  1.882788e+06    850  0.0  1.488665e+09
# KY      88173.0  3.803180e+06  7.012237e+05    708  0.0  3.355253e+08
# LA      67864.5  4.580123e+06  8.113491e+05    730  0.0  3.962653e+08
# MA     150005.0  6.672723e+06  7.127500e+05   3449  0.0  1.179891e+09
# MD      97554.5  9.689029e+06  2.132205e+06   1760  0.0  2.016428e+09
# ME      95004.5  4.722575e+06  1.427946e+06    474  0.0  5.981668e+08
# MI      98422.0  1.196914e+07  3.813911e+06   2458  0.0  7.821093e+09
# MN     129566.0  1.276570e+07  3.502700e+06   1449  0.0  3.156251e+09
# MO     131766.0  7.144136e+06  1.524053e+06   1503  0.0  1.827135e+09
# MS      61538.0  3.690209e+06  6.594804e+05    364  0.0  1.090937e+08
# MT      90988.0  5.162061e+06  2.573012e+06    344  0.0  8.546895e+08
# NC     144007.5  6.075217e+06  1.320078e+06   2368  0.0  2.740161e+09
# ND      57974.5  2.290681e+06  5.435800e+05    136  0.0  4.148076e+07
# NE     121468.5  1.159217e+07  4.680831e+06    608  0.0  2.668799e+09
# NH     127830.0  5.501119e+06  1.654176e+06    515  0.0  7.324887e+08
# NJ     112859.0  7.448192e+06  3.231423e+06   3284  0.0  1.055879e+10
# NM      90800.0  3.668181e+06  8.033809e+05    377  0.0  1.715934e+08
# NV     176896.5  3.124269e+06  4.818993e+05   2492  0.0  7.904735e+08
# NY     130526.0  1.394859e+07  1.999804e+06  11076  0.0  1.236476e+10
# OH     113943.0  4.306414e+06  4.114945e+05   3538  0.0  9.398785e+08
# OK      84546.0  8.340815e+06  2.385742e+06    968  0.0  2.094397e+09
# OR      76282.5  6.318970e+06  1.601172e+06    832  0.0  9.356045e+08
# PA     117163.5  6.105876e+06  9.383242e+05   5144  0.0  3.440949e+09
# PR     122445.0  3.490207e+06  1.272147e+06     22  0.0  1.965389e+07
# RI     234585.0  2.830253e+06  2.780573e+05   1759  0.0  3.844378e+08
# SC      71918.5  3.550876e+06  6.596179e+05    718  0.0  2.621023e+08
# SD     121424.5  9.831795e+06  3.860576e+06    190  0.0  6.902714e+08
# TN      86244.0  5.866136e+06  9.631785e+05   1089  0.0  7.868186e+08
# TX     119092.0  7.596256e+06  6.866227e+05   5867  0.0  1.964280e+09
# UT      43887.0  8.677868e+06  4.412548e+06    870  0.0  3.738994e+09
# VA      94333.5  4.943543e+06  6.712982e+05   1852  0.0  7.067873e+08
# VI     194432.0  2.204065e+06  1.047353e+06     11  0.0  9.050039e+06
# VT     105462.0  2.791000e+06  4.332693e+05    273  0.0  5.707481e+07
# WA     137402.0  6.769456e+07  4.268274e+07   1540  0.0  5.183022e+10
# WI     150243.0  4.229250e+06  5.070854e+05   2375  0.0  8.494265e+08
# WV     100762.0  2.889246e+06  4.668270e+05    353  0.0  1.143525e+08
# WY     138517.5  4.115691e+06  6.646454e+05    286  0.0  1.165312e+08
#
#
#           median
# STATE
# AK      339912.5
# AL      382920.5
# AR      301791.0
# AZ      361349.0
# CA      415070.0
# CO      391703.0
# CT      574580.0
# DC      685688.0
# DE     1126447.0
# FL      429696.0
# GA      329064.5
# HI      466973.5
# IA      324569.0
# ID      334287.0
# IL      656596.5
# IN      428730.5
# KS      468655.5
# KY      435831.5
# LA      281752.5
# MA      594359.0
# MD      439629.0
# ME      420095.5
# MI      403362.5
# MN      545704.0
# MO      480388.0
# MS      229953.5
# MT      439534.5
# NC      494480.5
# ND      244353.0
# NE      676183.5
# NH      506675.0
# NJ      458166.0
# NM      388575.0
# NV      553627.0
# NY      477653.0
# OH      490450.0
# OK      494863.5
# OR      404649.0
# PA      537987.0
# PR      147076.0
# RI      636549.0
# SC      293691.5
# SD      506610.0
# TN      373780.0
# TX      502072.0
# UT      163845.5
# VA      415526.5
# VI      230013.0
# VT      453692.0
# WA      524119.0
# WI      586919.0
# WV      477387.0
# WY      667078.5

# %%
# Generate the Plot (with Error Bars)
plt.figure(figsize=(20,8))
plt.plot(state_PC.index, state_PC["INCOME"]["median"], marker='o', color='b', label="Public Charity")
plt.plot(state_PF.index, state_PF["INCOME"]["median"], marker='x', color='g', label="Private Foundation")

# Add title, labels,  legend and grid
plt.title('Median Income vs State', color='k', size=14, weight='bold')
plt.xlabel('State')
plt.ylabel('Median Income')
plt.legend(loc="best")
plt.grid(alpha=0.5, axis='y')

# Save the Figure
#plt.savefig("../Images/TumorResponse.png")

# Show the Figure
plt.show()

# %%
# Generate the Plot (with Error Bars)
plt.figure(figsize=(20,8))
plt.plot(state_PC.index, state_PC["ASSETS"]["median"], marker='o', color='b', label="Public Charity")
plt.plot(state_PF.index, state_PF["ASSETS"]["median"], marker='x', color='g', label="Private Foundation")

# Add title, labels,  legend and grid
plt.title('Median Assets vs State', color='k', size=14, weight='bold')
plt.xlabel('State')
plt.ylabel('Median Assets')
plt.legend(loc="best")
plt.grid(alpha=0.5, axis='y')

# Save the Figure
#plt.savefig("../Images/TumorResponse.png")

# Show the Figure
plt.show()

# %%
# Plot Income vs Assets
plt.figure(figsize=(8,8))
plt.scatter(state_PC["ASSETS"]["median"], state_PC["INCOME"]["median"], c="b", marker='o', alpha=0.5, label="Public Charity")
plt.scatter(state_PF["ASSETS"]["median"], state_PF["INCOME"]["median"], c="g", marker='x', alpha=0.5, label="Private Foundation")
plt.title(f'Median Assets vs Median Income by State', size=14, weight='bold')
plt.xlabel('Median Assets')
plt.ylabel('Median Income')
#plt.xlim(lat_range)
plt.grid(alpha=0.5)
plt.legend(loc="best")

# Save the image
#plt.savefig("../Images/LatvsTemperature.png")
plt.show()

# %%
# Generate the Plot (with Error Bars)
plt.figure(figsize=(20,8))
plt.errorbar(state_PC.index, state_PC["INCOME"]["mean"],
             yerr=state_PC["INCOME"]["sem"], marker='o', color='b', linewidth=.2, label="Public Charity")
             #label=drugs[0], marker=scatter_marker[0], linewidth=scatter_line[0], color=scatter_color[0])
plt.errorbar(state_PF.index, state_PF["INCOME"]["mean"],
             yerr=state_PF["INCOME"]["sem"], marker='x', color='g', linewidth=.2, label="Private Foundation")
             #label=drugs[0], marker=scatter_marker[1], linewidth=scatter_line[1], color=scatter_color[1])

# Add title, labels,  legend and grid
plt.title('Income vs State', color='k', size=14, weight='bold')
plt.xlabel('State')
plt.ylabel('Income')
plt.legend(loc="best")
plt.grid(alpha=0.5, axis='y')

# Save the Figure
#plt.savefig("../Images/TumorResponse.png")

# Show the Figure
plt.show()

# %%
# Generate the Plot (with Error Bars)
plt.figure(figsize=(20,8))
plt.plot(state_PC.index, state_PC["INCOME"]["count"], marker='o', color='b', label="Public Charity")
plt.plot(state_PF.index, state_PF["INCOME"]["count"], marker='x', color='g', label="Private Foundation")

# Add title, labels,  legend and grid
plt.title('Count vs State', color='k', size=14, weight='bold')
plt.xlabel('State')
plt.ylabel('Count')
plt.legend(loc="best")
plt.grid(alpha=0.5, axis='y')

# Save the Figure
#plt.savefig("../Images/TumorResponse.png")

# Show the Figure
plt.show()

# %%
gov_data["STATE"].value_counts()
# Out:
# CA    98465
# TX    62551
# NY    62043
# FL    47986
# PA    37691
#       ...
# AP       21
# MP       21
# FM        3
# AA        1
# PW        1
# Name: STATE, Length: 61, dtype: int64

# %%
state_count = gov_data["STATE"].value_counts()
state_count
# Out:
# CA    98465
# TX    62551
# NY    62043
# FL    47986
# PA    37691
#       ...
# AP       21
# MP       21
# FM        3
# AA        1
# PW        1
# Name: STATE, Length: 61, dtype: int64

# %%
stats.chisquare(gov_data["STATE"].value_counts())
# Out:
# Power_divergenceResult(statistic=1298643.0452923914, pvalue=0.0)

# %%
# Plot Income vs State
plt.figure(figsize=(16,8))
plt.scatter(state_PC.index, state_PC["INCOME"]["count"], c="b", alpha=0.5, label="Public Charity")
plt.scatter(state_PF.index, state_PF["INCOME"]["count"], c="g", alpha=0.5, label="Private Foundation")

plt.title(f'Count by State', size=14, weight='bold')
plt.xlabel('State')
plt.ylabel('Count')
plt.xticks(rotation=90)
#plt.xlim(lat_range)
plt.grid(alpha=0.5)
plt.legend(loc="best")


# Save the image
#plt.savefig("../Images/LatvsTemperature.png")
plt.show()

# %%
# Plot Mean Income by State
plt.figure(figsize=(16,8))
plt.scatter(state_PC.index, state_PC["INCOME"]["mean"], c="b", alpha=0.5, label="Public Charity")
plt.scatter(state_PF.index, state_PF["INCOME"]["mean"], c="g", alpha=0.5, label="Private Foundation")

plt.title(f'Mean Income by State', size=14, weight='bold')
plt.xlabel('State')
plt.ylabel('Mean')
plt.xticks(rotation=90)
#plt.xlim(lat_range)
plt.grid(alpha=0.5)
plt.legend(loc="best")


# Save the image
#plt.savefig("../Images/LatvsTemperature.png")
plt.show()

# %%
# Plot sem Income by State
plt.figure(figsize=(16,8))
plt.scatter(state_PC.index, state_PC["INCOME"]["sem"], c="b", alpha=0.5, label="Public Charity")
plt.scatter(state_PF.index, state_PF["INCOME"]["sem"], c="g", alpha=0.5, label="Private Foundation")

plt.title(f'Sem Income by State', size=14, weight='bold')
plt.xlabel('State')
plt.ylabel('Sem')
plt.xticks(rotation=90)
#plt.xlim(lat_range)
plt.grid(alpha=0.5)
plt.legend(loc="best")


# Save the image
#plt.savefig("../Images/LatvsTemperature.png")
plt.show()

# %%
# Plot Income vs State
plt.figure(figsize=(16,8))
plt.scatter(gov_data["STATE"], gov_data["INCOME"], c="b", alpha=0.5)
plt.title(f'State vs Income', size=14, weight='bold')
plt.xlabel('State')
plt.ylabel('Income')
plt.xticks(rotation=90)
#plt.xlim(lat_range)
plt.grid(alpha=0.5)

# Save the image
#plt.savefig("../Images/LatvsTemperature.png")
plt.show()

# %%
# Plot Income vs Assets
plt.figure(figsize=(8,8))
plt.scatter(gov_data["ASSETS"], gov_data["INCOME"], c="b", alpha=0.5)
plt.title(f'Assets vs Income', size=14, weight='bold')
plt.xlabel('Assets')
plt.ylabel('Income')
#plt.xlim(lat_range)
plt.grid(alpha=0.5)

# Save the image
#plt.savefig("../Images/LatvsTemperature.png")
plt.show()

# %%
x_labels1 = gov_data["LEVEL1"].map(dict_Level1["Description1"])
x_labels1
# Out:
# 18             Public Charity
# 19             Public Charity
# 20             Public Charity
# 21             Public Charity
# 33             Public Charity
#                   ...
# 1499443    Private Foundation
# 1499444    Private Foundation
# 1499445    Private Foundation
# 1499447    Private Foundation
# 1499448        Public Charity
# Name: LEVEL1, Length: 891408, dtype: object

# %%
x_labels2 = gov_data["LEVEL2"].map(dict_Level2["Description2"])
x_labels2
# Out:
# 18          Operating Public Charity
# 19          Operating Public Charity
# 20          Operating Public Charity
# 21          Operating Public Charity
# 33          Operating Public Charity
#                      ...
# 1499443    Supporting Public Charity
# 1499444    Supporting Public Charity
# 1499445    Supporting Public Charity
# 1499447     Operating Public Charity
# 1499448    Supporting Public Charity
# Name: LEVEL2, Length: 891408, dtype: object

# %%
x_labels3 = gov_data["LEVEL3"].map(dict_Level3["Description3"])
x_labels3
# Out:
# 18                Public, societal benefit
# 19                Public, societal benefit
# 20                          Human Services
# 21                          Human Services
# 33            Arts, culture and humanities
#                         ...
# 1499443           Public, societal benefit
# 1499444    Private grantmaking foundations
# 1499445    Private grantmaking foundations
# 1499447                     Human Services
# 1499448        Single organization support
# Name: LEVEL3, Length: 891408, dtype: object

# %%
x_labels4 = gov_data["LEVEL4"].map(dict_Level4["Description4"])
x_labels4
# Out:
# 18                  Community Improvement, Capacity Building
# 19                  Community Improvement, Capacity Building
# 20                    Recreation, Sports, Leisure, Athletics
# 21                    Recreation, Sports, Leisure, Athletics
# 33                             Arts, Culture, and Humanities
#                                  ...
# 1499443    Science and Technology Research Institutes, Se...
# 1499444    Philanthropy, Voluntarism, and Grantmaking Fou...
# 1499445    Philanthropy, Voluntarism, and Grantmaking Fou...
# 1499447              Human Services - Multipurpose and Other
# 1499448                                            Education
# Name: LEVEL4, Length: 891408, dtype: object

# %%
# Plot Income vs level1
plt.figure(figsize=(8,8))
plt.scatter(x_labels1, gov_data["INCOME"], c="b", alpha=0.5)
plt.title(f'Level1 vs Income', size=14, weight='bold')
plt.xlabel('Level1')
plt.ylabel('Income')
#plt.xlim(lat_range)
plt.grid(alpha=0.5)

# Save the image
#plt.savefig("../Images/LatvsTemperature.png")
plt.show()

# %%
# Plot Income vs level2
plt.figure(figsize=(8,8))
plt.scatter(x_labels2, gov_data["INCOME"], c="b", alpha=0.5)
plt.title(f'Level2 vs Income', size=14, weight='bold')
plt.xlabel('Level2')
plt.ylabel('Income')
#plt.xlim(lat_range)
plt.grid(alpha=0.5)

# Save the image
#plt.savefig("../Images/LatvsTemperature.png")
plt.show()

# %%
# Plot Income vs level3
plt.figure(figsize=(8,8))
plt.scatter(x_labels3, gov_data["INCOME"], c="b", alpha=0.5)
plt.title(f'Level3 vs Income', size=14, weight='bold')
plt.xlabel('Level3')
plt.xticks(rotation=90)
plt.ylabel('Income')
#plt.xlim(lat_range)
plt.grid(alpha=0.5)

# Save the image
#plt.savefig("../Images/LatvsTemperature.png")
plt.show()

# %%
# Plot Income vs level4
plt.figure(figsize=(8,8))
plt.scatter(x_labels4, gov_data["INCOME"], c="b", alpha=0.5)
plt.title(f'Level4 vs Income', size=14, weight='bold')
plt.xlabel('Level4')
plt.xticks(rotation=90)
plt.ylabel('Income')
#plt.xlim(lat_range)
plt.grid(alpha=0.5)

# Save the image
#plt.savefig("../Images/LatvsTemperature.png")
plt.show()
# Out:
# C:\Users\katro\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\katro\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# Plot Assets vs level1
plt.figure(figsize=(8,8))
plt.scatter(x_labels1, gov_data["ASSETS"], c="b", alpha=0.5)
plt.title(f'Level1 vs Assets', size=14, weight='bold')
plt.xlabel('Level1')
plt.ylabel('Assets')
#plt.xlim(lat_range)
plt.grid(alpha=0.5)

# Save the image
#plt.savefig("../Images/LatvsTemperature.png")
plt.show()

# %%
# Plot Income vs level2
plt.figure(figsize=(8,8))
plt.scatter(x_labels2, gov_data["ASSETS"], c="b", alpha=0.5)
plt.title(f'Level2 vs Assets', size=14, weight='bold')
plt.xlabel('Level2')
plt.ylabel('Assets')
#plt.xlim(lat_range)
plt.grid(alpha=0.5)

# Save the image
#plt.savefig("../Images/LatvsTemperature.png")
plt.show()

# %%
# Plot Income vs level3
plt.figure(figsize=(8,8))
plt.scatter(x_labels3, gov_data["ASSETS"], c="b", alpha=0.5)
plt.title(f'Level3 vs Assets', size=14, weight='bold')
plt.xlabel('Level3')
plt.xticks(rotation=90)
plt.ylabel('Assets')
#plt.xlim(lat_range)
plt.grid(alpha=0.5)

# Save the image
#plt.savefig("../Images/LatvsTemperature.png")
plt.show()

# %%
# Plot Income vs level4
plt.figure(figsize=(8,8))
plt.scatter(x_labels4, gov_data["ASSETS"], c="b", alpha=0.5)
plt.title(f'Level4 vs Assets', size=14, weight='bold')
plt.xlabel('Level4')
plt.xticks(rotation=90)
plt.ylabel('Assets')
#plt.xlim(lat_range)
plt.grid(alpha=0.5)

# Save the image
#plt.savefig("../Images/LatvsTemperature.png")
plt.show()

# %%
value1 = gov_data.loc[(gov_data["LEVEL3"] == "MO"), ["ASSETS", "INCOME"]]["INCOME"]
value1
value1.describe()
# Out:
# count    2.691000e+03
# mean     2.121791e+06
# std      1.853430e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      8.023050e+04
# max      4.340227e+08
# Name: INCOME, dtype: float64

# %%
value2 = gov_data.loc[(gov_data["LEVEL3"] == "EN"), ["ASSETS", "INCOME"]]["INCOME"]
type(value2)
value2.describe()
# Out:
# count    4.188400e+04
# mean     6.195591e+05
# std      7.824603e+06
# min     -5.300000e+01
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.133168e+05
# max      7.751803e+08
# Name: INCOME, dtype: float64

# %%
box_plot_data=[value1,value2]
plt.boxplot(box_plot_data)
plt.show()

# %%
gov_data.boxplot("INCOME", by="LEVEL1", figsize=(20, 10))

# %%
stats.f_oneway(value1, value2)
# Out:
# F_onewayResult(statistic=72.91191021889728, pvalue=1.397796316084028e-17)

# %%
gov_data.boxplot("INCOME", by="LEVEL2", figsize=(20, 10))

# %%
stats.f_oneway(gov_data[gov_data["LEVEL2"] == "M"]["INCOME"], 
               gov_data[gov_data["LEVEL2"] == "O"]["INCOME"],
              gov_data[gov_data["LEVEL2"] == "S"]["INCOME"])
# Out:
# F_onewayResult(statistic=0.9425877630287551, pvalue=0.38961867846674714)

# %%
stats.f_oneway(gov_data[gov_data["LEVEL1"] == "PC"]["INCOME"], 
               gov_data[gov_data["LEVEL1"] == "PF"]["INCOME"])
# Out:
# F_onewayResult(statistic=0.031332006215250514, pvalue=0.859501759588856)

# %%
gov_data.to_csv(index=False, path_or_buf="gov_data.csv")

# %%
stats.f_oneway(state_PC["INCOME"]["median"], 
               state_PF["INCOME"]["median"])
# Out:
# F_onewayResult(statistic=105.89219949166548, pvalue=8.40558929233472e-18)

# %%
stats.f_oneway(state_PC["ASSETS"]["median"], 
               state_PF["ASSETS"]["median"])
# Out:
# F_onewayResult(statistic=46.26349437711653, pvalue=5.626218026605068e-10)
